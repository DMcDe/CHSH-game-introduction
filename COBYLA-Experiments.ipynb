# %% [markdown]
# # Improving Brewster Paper
#
# In the original paper **General characterization of qubit-preserving impairments on two-qubit Bell nonlocality**, a technique was presented that would correct errors such as polarization misalignments of entangled qubits by optimizing a set of unitary gets for each of the qubits Alice and Bob have. A follow up paper, **Automated Bell inequality violation searches for estimating entanglement quality in fiber**, determined that the Nelder-Mead Method was deemed to be the best method for optimization, though Bayesian Optimization was also quoted as being a close second.
#
# Previous work on this repo has simulated CHSH games on a quantum network using SeQuEnCe, with more recent additions implementing polarization misalignment and the proposed corrective technique by the above papers. However, we believe that we can improve this process further by utilizing more suitable optimization techniques. The below experiment uses COnstrained Optimization BY Linear Approximation, or COBYLA, to better approximate better alphas in a noisy quantum environment.

# %%
import network_module
from scipy.optimize import minimize
import numpy as np

# %%
theta1 = 0.7854          
theta2 = 0          
theta3 = -0.3927        
theta4 = 0.3927

# %%
#Bayesian Optimization function
from bayes_opt import BayesianOptimization
import numpy as np

def BayesOPT(deltas,fidelity=1000):
    iteration_s_values = []

    #play chsh game
    def simulated_chsh(alpha1, alpha2, alpha3, alpha4, alpha5, alpha6):
        g = network_module.Game(deltas = deltas,fid = 0.9)
        alphas_alice = [alpha1,alpha2,alpha3]
        alphas_bob = [alpha4,alpha5,alpha6]
        result = g.start(fidelity,theta1,theta2,theta3,theta4,alphas_alice,alphas_bob)
        S = g.referee.compute_chsh_s()
        iteration_s_values.append(S)
        return S

    # Define Bayesian optimizer bounds for Alice’s PC angles (voltages mapped to angles)
    pbounds = {
        'alpha1': (-np.pi, np.pi),
        'alpha2': (-np.pi, np.pi),
        'alpha3': (-np.pi, np.pi),
        'alpha4': (-np.pi, np.pi),
        'alpha5': (-np.pi, np.pi),
        'alpha6': (-np.pi, np.pi),
    }

    # Create optimizer
    optimizer = BayesianOptimization(
        f=simulated_chsh,
        pbounds=pbounds,
        verbose=0
    )

    import time

    start_time = time.time()
    # Run optimization manually with acquisition function
    optimizer.maximize(
        init_points=4,
        n_iter=26
    )


    end_time = time.time()
    return list(optimizer.max['params'].values()),end_time - start_time,np.maximum.accumulate(iteration_s_values)

# %%
from scipy.optimize import minimize
import numpy as np
import time

def NelderMeadOPT(deltas, fidelity=1000):
    iteration_s_values = []

    # Objective function (negative S, since Nelder-Mead minimizes)
    def simulated_chsh(angles):
        alpha1, alpha2, alpha3, alpha4, alpha5, alpha6 = angles
        g = network_module.Game(deltas=deltas, fid=0.9)
        alphas_alice = [alpha1, alpha2, alpha3]
        alphas_bob = [alpha4, alpha5, alpha6]
        result = g.start(fidelity, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
        S = g.referee.compute_chsh_s()
        iteration_s_values.append(S)
        # print("S:",S)
        return -S  # Negative because we want to maximize S

    # Initial guess (can be random or zeros)
    x0 = np.random.uniform(-np.pi, np.pi, size=6)

    # Run optimization
    start_time = time.time()
    result = minimize(
        simulated_chsh,
        x0,
        method='Nelder-Mead',
        options={'maxiter': 30, 'disp': True}
    )
    end_time = time.time()
    
    best_angles = result.x.tolist()
    best_time = end_time - start_time
    s_curve = np.maximum.accumulate(iteration_s_values)
    

    return best_angles, best_time, s_curve

# %%
# deltaA = np.random.uniform(-np.pi, np.pi, size=3).tolist()
# deltaB = np.random.uniform(-np.pi, np.pi, size=3).tolist()
# deltas = [deltaA ,deltaB]

# %%
#COBYLA function
import numpy as np
from scipy.optimize import minimize

# Number of shots per evaluation
# shots = 2500
COBYLA_evals = []
COBYLA_progress = []
def COBYLA_OPT(deltas,fidelity=1000):
    def objective(x):
        alphas_alice = x[0:3]
        alphas_bob   = x[3:6]

        # Start a new game for each evaluation to avoid stale state
        g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9)
        result = g.start(fidelity, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
        S = g.referee.compute_chsh_s()
        print(result,S)
        COBYLA_evals.append(S)
        best_so_far = max(COBYLA_evals)
        COBYLA_progress.append(best_so_far)
    
        return -S  # minimize negative S to maximize S

# Construct COBYLA inequality constraints for [-pi, pi]
    pi_val = np.pi
    cons = []
    for i in range(6):
    # x[i] >= -pi  ->  x[i] + pi >= 0
        cons.append({'type': 'ineq', 'fun': lambda x, i=i: x[i] + pi_val})
    # x[i] <= pi   ->  pi - x[i] >= 0
        cons.append({'type': 'ineq', 'fun': lambda x, i=i: pi_val - x[i]})

    x0 = np.random.uniform(-np.pi, np.pi, size=6)
    res = minimize(objective, x0, method='COBYLA',constraints=cons,
               options={'rhobeg': 1.0, 'tol': 1e-6, 'maxiter': 30})

    return x0

# %%
#Experiments
import time
num_exp = 5

#convergence progress
BO_conv = []
NM_conv = []
COB_conv = []

#validation results
BO_res = []
NM_res = []
COB_res = []

#Time results
BO_time = []
NM_time = []
COB_time = []

for x in range(num_exp):
    print("Iteration:",x)
    deltaA = np.random.uniform(-np.pi, np.pi, size=3).tolist()
    deltaB = np.random.uniform(-np.pi, np.pi, size=3).tolist()
    deltas = [deltaA ,deltaB]

    #Bayesian Optimization
    # start_time = time.time()
    # X_high_fid, time_high_fid,progress = BayesOPT(deltas,fidelity=2500)
    # end_time = time.time()
    # BO_conv.append(progress)
    # BO_time.append(end_time-start_time)
    # alphas_alice = X_high_fid[0:3]
    # alphas_bob = X_high_fid[3:6]

    # #Verifying "True" value of Baysian Optimization
    # g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9)
    # g.start(10000,theta1,theta2,theta3,theta4,alphas_alice,alphas_bob)
    # S_high = g.referee.compute_chsh_s()
    # # print("S HIGH FID:",S_high)
    # BO_res.append(S_high)
    
    # start_time = time.time()
    # X_high_fid, time_high_fid,progress = NelderMeadOPT(deltas,fidelity=2500)
    # end_time = time.time()
    # NM_conv.append(progress)
    # NM_time.append(end_time-start_time)
    # alphas_alice = X_high_fid[0:3]
    # alphas_bob = X_high_fid[3:6]

    # #Verifying "True" value of NelderMeadOPT
    # g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9)
    # g.start(10000,theta1,theta2,theta3,theta4,alphas_alice,alphas_bob)
    # S_high = g.referee.compute_chsh_s()
    # print("S HIGH FID:",S_high)
    # NM_res.append(S_high)

    #COBYLA
    COBYLA_evals = []
    COBYLA_progress = []
    start_time = time.time()
    # x0 = np.zeros(6)
    # res = minimize(objective, x0, method='COBYLA',constraints=cons,
    #            options={'rhobeg': 1.0, 'tol': 1e-6, 'maxiter': 30})
    # print(deltas)
    res = COBYLA_OPT(deltas,fidelity=2500)
    # print(deltas)
    end_time = time.time()
    COB_time.append(end_time-start_time)
    COB_conv.append(COBYLA_progress)

    #Verifying "True" value of COBYLA
    alphas_alice = res[0:3]
    alphas_bob = res[3:]
    # print(deltas)
    g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9)
    
    result = g.start(10000, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
    S = g.referee.compute_chsh_s()
    print("Win rate:",result,"S:",S)
    # if result < 0.7:
    #     g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9,debug=True)
    #     result = g.start(100, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
    #     break
    
    print(S)
    COB_res.append(S)
# Out:
# Iteration: 0
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.815, winrate = 0.092, rounds = 628
#   Setting (0, 1): E = 0.065, winrate = 0.533, rounds = 599
#   Setting (1, 0): E = -0.067, winrate = 0.466, rounds = 641
#   Setting (1, 1): E = 0.424, winrate = 0.288, rounds = 632
# Global S = -1.2413, Global winrate = 0.3432
#
# 0.3432 -1.2413114262322291
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.164, winrate = 0.582, rounds = 622
#   Setting (0, 1): E = -0.800, winrate = 0.100, rounds = 650
#   Setting (1, 0): E = 0.063, winrate = 0.531, rounds = 638
#   Setting (1, 1): E = 0.302, winrate = 0.349, rounds = 590
# Global S = -0.8750, Global winrate = 0.3888
#
# 0.3888 -0.8750118522256815
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.006, winrate = 0.503, rounds = 654
#   Setting (0, 1): E = 0.552, winrate = 0.776, rounds = 612
#   Setting (1, 0): E = -0.239, winrate = 0.380, rounds = 610
#   Setting (1, 1): E = 0.609, winrate = 0.196, rounds = 624
# Global S = -0.2899, Global winrate = 0.4632
#
# 0.4632 -0.2899148316190241
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.049, winrate = 0.476, rounds = 654
#   Setting (0, 1): E = 0.554, winrate = 0.777, rounds = 601
#   Setting (1, 0): E = -0.651, winrate = 0.175, rounds = 624
#   Setting (1, 1): E = -0.337, winrate = 0.668, rounds = 621
# Global S = 0.1911, Global winrate = 0.5208
#
# 0.5208 0.19105979510150656
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.199, winrate = 0.400, rounds = 622
#   Setting (0, 1): E = 0.344, winrate = 0.672, rounds = 607
#   Setting (1, 0): E = -0.788, winrate = 0.106, rounds = 641
#   Setting (1, 1): E = 0.181, winrate = 0.410, rounds = 630
# Global S = -0.8238, Global winrate = 0.3932
#
# 0.3932 -0.8238244976762571
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.752, winrate = 0.876, rounds = 620
#   Setting (0, 1): E = -0.280, winrate = 0.360, rounds = 583
#   Setting (1, 0): E = 0.073, winrate = 0.536, rounds = 658
#   Setting (1, 1): E = 0.740, winrate = 0.130, rounds = 639
# Global S = -0.1952, Global winrate = 0.4756
#
# 0.4756 -0.19524619703059454
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.792, winrate = 0.896, rounds = 595
#   Setting (0, 1): E = -0.262, winrate = 0.369, rounds = 618
#   Setting (1, 0): E = -0.259, winrate = 0.370, rounds = 629
#   Setting (1, 1): E = -0.842, winrate = 0.921, rounds = 658
# Global S = 1.1123, Global winrate = 0.6400
#
# 0.64 1.1122645106435525
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.341, winrate = 0.671, rounds = 656
#   Setting (0, 1): E = 0.222, winrate = 0.611, rounds = 625
#   Setting (1, 0): E = -0.802, winrate = 0.099, rounds = 626
#   Setting (1, 1): E = -0.029, winrate = 0.514, rounds = 593
# Global S = -0.2094, Global winrate = 0.4756
#
# 0.4756 -0.20938572737944133
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.123, winrate = 0.562, rounds = 616
#   Setting (0, 1): E = -0.478, winrate = 0.261, rounds = 655
#   Setting (1, 0): E = -0.517, winrate = 0.241, rounds = 605
#   Setting (1, 1): E = -0.647, winrate = 0.824, rounds = 624
# Global S = -0.2244, Global winrate = 0.4708
#
# 0.4708 -0.22440544650815297
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.770, winrate = 0.885, rounds = 652
#   Setting (0, 1): E = -0.273, winrate = 0.363, rounds = 630
#   Setting (1, 0): E = -0.151, winrate = 0.425, rounds = 617
#   Setting (1, 1): E = -0.631, winrate = 0.815, rounds = 601
# Global S = 0.9768, Global winrate = 0.6232
#
# 0.6232 0.9768090823955498
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.862, winrate = 0.931, rounds = 637
#   Setting (0, 1): E = -0.133, winrate = 0.434, rounds = 602
#   Setting (1, 0): E = 0.090, winrate = 0.545, rounds = 635
#   Setting (1, 1): E = -0.473, winrate = 0.736, rounds = 626
# Global S = 1.2916, Global winrate = 0.6644
#
# 0.6644 1.291569297839292
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.677, winrate = 0.838, rounds = 606
#   Setting (0, 1): E = -0.472, winrate = 0.264, rounds = 640
#   Setting (1, 0): E = -0.449, winrate = 0.276, rounds = 617
#   Setting (1, 1): E = -0.419, winrate = 0.710, rounds = 637
# Global S = 0.1749, Global winrate = 0.5196
#
# 0.5196 0.17489841766372738
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.585, winrate = 0.792, rounds = 612
#   Setting (0, 1): E = 0.577, winrate = 0.788, rounds = 671
#   Setting (1, 0): E = 0.124, winrate = 0.562, rounds = 596
#   Setting (1, 1): E = -0.069, winrate = 0.535, rounds = 621
# Global S = 1.3551, Global winrate = 0.6724
#
# 0.6724 1.3551226680213437
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.642, winrate = 0.821, rounds = 609
#   Setting (0, 1): E = 0.563, winrate = 0.782, rounds = 623
#   Setting (1, 0): E = -0.200, winrate = 0.400, rounds = 635
#   Setting (1, 1): E = 0.276, winrate = 0.362, rounds = 633
# Global S = 0.7290, Global winrate = 0.5880
#
# 0.588 0.7289777186216899
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.569, winrate = 0.785, rounds = 608
#   Setting (0, 1): E = 0.454, winrate = 0.727, rounds = 656
#   Setting (1, 0): E = 0.451, winrate = 0.726, rounds = 627
#   Setting (1, 1): E = 0.222, winrate = 0.389, rounds = 609
# Global S = 1.2530, Global winrate = 0.6584
#
# 0.6584 1.2530280250860348
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.377, winrate = 0.689, rounds = 604
#   Setting (0, 1): E = 0.623, winrate = 0.812, rounds = 626
#   Setting (1, 0): E = 0.098, winrate = 0.549, rounds = 603
#   Setting (1, 1): E = 0.256, winrate = 0.372, rounds = 667
# Global S = 0.8420, Global winrate = 0.6012
#
# 0.6012 0.8419589372733204
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.141, winrate = 0.571, rounds = 645
#   Setting (0, 1): E = 0.216, winrate = 0.608, rounds = 602
#   Setting (1, 0): E = 0.766, winrate = 0.883, rounds = 616
#   Setting (1, 1): E = 0.322, winrate = 0.339, rounds = 637
# Global S = 0.8014, Global winrate = 0.5976
#
# 0.5976 0.801444845298666
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.650, winrate = 0.825, rounds = 605
#   Setting (0, 1): E = 0.618, winrate = 0.809, rounds = 613
#   Setting (1, 0): E = 0.453, winrate = 0.726, rounds = 625
#   Setting (1, 1): E = -0.364, winrate = 0.682, rounds = 657
# Global S = 2.0844, Global winrate = 0.7588
#
# 0.7588 2.084432309844723
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.149, winrate = 0.575, rounds = 670
#   Setting (0, 1): E = 0.685, winrate = 0.842, rounds = 596
#   Setting (1, 0): E = 0.818, winrate = 0.909, rounds = 617
#   Setting (1, 1): E = -0.287, winrate = 0.643, rounds = 617
# Global S = 1.9392, Global winrate = 0.7380
#
# 0.738 1.9391659500242795
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.818, winrate = 0.909, rounds = 638
#   Setting (0, 1): E = 0.361, winrate = 0.680, rounds = 629
#   Setting (1, 0): E = 0.145, winrate = 0.572, rounds = 636
#   Setting (1, 1): E = -0.615, winrate = 0.807, rounds = 597
# Global S = 1.9385, Global winrate = 0.7416
#
# 0.7416 1.938466576808118
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.842, winrate = 0.921, rounds = 596
#   Setting (0, 1): E = 0.191, winrate = 0.596, rounds = 611
#   Setting (1, 0): E = 0.195, winrate = 0.597, rounds = 683
#   Setting (1, 1): E = -0.728, winrate = 0.864, rounds = 610
# Global S = 1.9564, Global winrate = 0.7392
#
# 0.7392 1.9563692295197574
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.561, winrate = 0.781, rounds = 606
#   Setting (0, 1): E = 0.493, winrate = 0.747, rounds = 663
#   Setting (1, 0): E = 0.689, winrate = 0.845, rounds = 637
#   Setting (1, 1): E = -0.236, winrate = 0.618, rounds = 594
# Global S = 1.9791, Global winrate = 0.7492
#
# 0.7492 1.9791269858663152
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.668, winrate = 0.834, rounds = 591
#   Setting (0, 1): E = 0.504, winrate = 0.752, rounds = 597
#   Setting (1, 0): E = 0.445, winrate = 0.722, rounds = 645
#   Setting (1, 1): E = -0.364, winrate = 0.682, rounds = 667
# Global S = 1.9818, Global winrate = 0.7452
#
# 0.7452 1.9818254001236484
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.496, winrate = 0.748, rounds = 627
#   Setting (0, 1): E = 0.617, winrate = 0.809, rounds = 622
#   Setting (1, 0): E = 0.668, winrate = 0.834, rounds = 609
#   Setting (1, 1): E = -0.221, winrate = 0.611, rounds = 642
# Global S = 2.0029, Global winrate = 0.7488
#
# 0.7488 2.002868606636615
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.466, winrate = 0.733, rounds = 610
#   Setting (0, 1): E = 0.547, winrate = 0.773, rounds = 618
#   Setting (1, 0): E = 0.800, winrate = 0.900, rounds = 639
#   Setting (1, 1): E = -0.207, winrate = 0.603, rounds = 633
# Global S = 2.0191, Global winrate = 0.7528
#
# 0.7528 2.019137374645702
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.420, winrate = 0.710, rounds = 614
#   Setting (0, 1): E = 0.577, winrate = 0.788, rounds = 666
#   Setting (1, 0): E = 0.750, winrate = 0.875, rounds = 593
#   Setting (1, 1): E = -0.362, winrate = 0.681, rounds = 627
# Global S = 2.1092, Global winrate = 0.7628
#
# 0.7628 2.109235068780818
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.452, winrate = 0.726, rounds = 664
#   Setting (0, 1): E = 0.310, winrate = 0.655, rounds = 635
#   Setting (1, 0): E = 0.741, winrate = 0.871, rounds = 634
#   Setting (1, 1): E = -0.347, winrate = 0.674, rounds = 567
# Global S = 1.8508, Global winrate = 0.7328
#
# 0.7328 1.8508110512997644
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.373, winrate = 0.686, rounds = 606
#   Setting (0, 1): E = 0.490, winrate = 0.745, rounds = 600
#   Setting (1, 0): E = 0.780, winrate = 0.890, rounds = 663
#   Setting (1, 1): E = -0.357, winrate = 0.678, rounds = 631
# Global S = 1.9993, Global winrate = 0.7524
#
# 0.7524 1.9993029944653542
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.488, winrate = 0.744, rounds = 586
#   Setting (0, 1): E = 0.602, winrate = 0.801, rounds = 654
#   Setting (1, 0): E = 0.696, winrate = 0.848, rounds = 664
#   Setting (1, 1): E = -0.497, winrate = 0.748, rounds = 596
# Global S = 2.2829, Global winrate = 0.7876
#
# 0.7876 2.2829285185210946
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.389, winrate = 0.694, rounds = 599
#   Setting (0, 1): E = 0.630, winrate = 0.815, rounds = 621
#   Setting (1, 0): E = 0.719, winrate = 0.860, rounds = 591
#   Setting (1, 1): E = -0.431, winrate = 0.716, rounds = 689
# Global S = 2.1688, Global winrate = 0.7692
#
# 0.7692 2.1687909075847243
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.845, winrate = 0.078, rounds = 2538
#   Setting (0, 1): E = 0.088, winrate = 0.544, rounds = 2444
#   Setting (1, 0): E = -0.083, winrate = 0.459, rounds = 2568
#   Setting (1, 1): E = 0.443, winrate = 0.278, rounds = 2450
# Global S = -1.2822, Global winrate = 0.3387
#
# Win rate: 0.3387 S: -1.282199771125715
# -1.282199771125715
# Iteration: 1
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.684, winrate = 0.158, rounds = 607
#   Setting (0, 1): E = 0.200, winrate = 0.600, rounds = 575
#   Setting (1, 0): E = -0.149, winrate = 0.426, rounds = 653
#   Setting (1, 1): E = 0.805, winrate = 0.098, rounds = 665
# Global S = -1.4367, Global winrate = 0.3136
#
# 0.3136 -1.436746734371647
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.692, winrate = 0.154, rounds = 623
#   Setting (0, 1): E = 0.320, winrate = 0.660, rounds = 621
#   Setting (1, 0): E = 0.433, winrate = 0.717, rounds = 660
#   Setting (1, 1): E = -0.017, winrate = 0.508, rounds = 596
# Global S = 0.0787, Global winrate = 0.5128
#
# 0.5128 0.0787489383181885
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.136, winrate = 0.568, rounds = 618
#   Setting (0, 1): E = 0.377, winrate = 0.688, rounds = 613
#   Setting (1, 0): E = -0.251, winrate = 0.374, rounds = 609
#   Setting (1, 1): E = 0.785, winrate = 0.108, rounds = 660
# Global S = -0.5233, Global winrate = 0.4288
#
# 0.4288 -0.5233224453033948
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.717, winrate = 0.141, rounds = 644
#   Setting (0, 1): E = 0.284, winrate = 0.642, rounds = 651
#   Setting (1, 0): E = -0.462, winrate = 0.269, rounds = 624
#   Setting (1, 1): E = -0.752, winrate = 0.876, rounds = 581
# Global S = -0.1426, Global winrate = 0.4744
#
# 0.4744 -0.1426001154874572
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.168, winrate = 0.584, rounds = 579
#   Setting (0, 1): E = 0.871, winrate = 0.936, rounds = 622
#   Setting (1, 0): E = -0.710, winrate = 0.145, rounds = 675
#   Setting (1, 1): E = 0.112, winrate = 0.444, rounds = 624
# Global S = 0.2171, Global winrate = 0.5180
#
# 0.518 0.2171037443718749
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.863, winrate = 0.069, rounds = 598
#   Setting (0, 1): E = 0.030, winrate = 0.515, rounds = 660
#   Setting (1, 0): E = -0.104, winrate = 0.448, rounds = 625
#   Setting (1, 1): E = -0.459, winrate = 0.729, rounds = 617
# Global S = -0.4779, Global winrate = 0.4444
#
# 0.4444 -0.4779022352227905
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.586, winrate = 0.793, rounds = 628
#   Setting (0, 1): E = 0.461, winrate = 0.730, rounds = 601
#   Setting (1, 0): E = -0.412, winrate = 0.294, rounds = 609
#   Setting (1, 1): E = -0.142, winrate = 0.571, rounds = 662
# Global S = 0.7767, Global winrate = 0.5976
#
# 0.5976 0.7767286540227833
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.764, winrate = 0.882, rounds = 644
#   Setting (0, 1): E = -0.422, winrate = 0.289, rounds = 633
#   Setting (1, 0): E = -0.475, winrate = 0.262, rounds = 625
#   Setting (1, 1): E = -0.512, winrate = 0.756, rounds = 598
# Global S = 0.3787, Global winrate = 0.5468
#
# 0.5468 0.3786798930309336
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.538, winrate = 0.769, rounds = 632
#   Setting (0, 1): E = -0.116, winrate = 0.442, rounds = 627
#   Setting (1, 0): E = -0.365, winrate = 0.318, rounds = 595
#   Setting (1, 1): E = 0.700, winrate = 0.150, rounds = 646
# Global S = -0.6428, Global winrate = 0.4196
#
# 0.4196 -0.6428490335023234
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.652, winrate = 0.826, rounds = 610
#   Setting (0, 1): E = 0.461, winrate = 0.730, rounds = 649
#   Setting (1, 0): E = -0.472, winrate = 0.264, rounds = 598
#   Setting (1, 1): E = 0.194, winrate = 0.403, rounds = 643
# Global S = 0.4472, Global winrate = 0.5580
#
# 0.558 0.447194648613646
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.708, winrate = 0.854, rounds = 658
#   Setting (0, 1): E = 0.213, winrate = 0.606, rounds = 620
#   Setting (1, 0): E = -0.455, winrate = 0.272, rounds = 617
#   Setting (1, 1): E = -0.048, winrate = 0.524, rounds = 605
# Global S = 0.5136, Global winrate = 0.5692
#
# 0.5692 0.5136142994651818
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.757, winrate = 0.878, rounds = 608
#   Setting (0, 1): E = 0.482, winrate = 0.741, rounds = 625
#   Setting (1, 0): E = -0.029, winrate = 0.485, rounds = 620
#   Setting (1, 1): E = 0.147, winrate = 0.427, rounds = 647
# Global S = 1.0623, Global winrate = 0.6296
#
# 0.6296 1.0623151591648012
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.615, winrate = 0.807, rounds = 602
#   Setting (0, 1): E = 0.654, winrate = 0.827, rounds = 648
#   Setting (1, 0): E = 0.460, winrate = 0.730, rounds = 652
#   Setting (1, 1): E = -0.582, winrate = 0.791, rounds = 598
# Global S = 2.3110, Global winrate = 0.7884
#
# 0.7884 2.3110014265712633
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.250, winrate = 0.625, rounds = 619
#   Setting (0, 1): E = 0.808, winrate = 0.904, rounds = 647
#   Setting (1, 0): E = 0.799, winrate = 0.900, rounds = 628
#   Setting (1, 1): E = -0.168, winrate = 0.584, rounds = 606
# Global S = 2.0264, Global winrate = 0.7564
#
# 0.7564 2.0264299795214513
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.657, winrate = 0.829, rounds = 613
#   Setting (0, 1): E = 0.574, winrate = 0.787, rounds = 662
#   Setting (1, 0): E = 0.371, winrate = 0.685, rounds = 623
#   Setting (1, 1): E = -0.545, winrate = 0.772, rounds = 602
# Global S = 2.1471, Global winrate = 0.7684
#
# 0.7684 2.1470776543159307
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.502, winrate = 0.751, rounds = 662
#   Setting (0, 1): E = 0.617, winrate = 0.808, rounds = 621
#   Setting (1, 0): E = 0.622, winrate = 0.811, rounds = 588
#   Setting (1, 1): E = -0.587, winrate = 0.793, rounds = 629
# Global S = 2.3274, Global winrate = 0.7900
#
# 0.79 2.3273522045729473
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.034, winrate = 0.517, rounds = 656
#   Setting (0, 1): E = 0.641, winrate = 0.821, rounds = 624
#   Setting (1, 0): E = 0.838, winrate = 0.919, rounds = 582
#   Setting (1, 1): E = -0.207, winrate = 0.603, rounds = 638
# Global S = 1.7199, Global winrate = 0.7084
#
# 0.7084 1.7199467506242239
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.266, winrate = 0.633, rounds = 654
#   Setting (0, 1): E = 0.618, winrate = 0.809, rounds = 613
#   Setting (1, 0): E = 0.692, winrate = 0.846, rounds = 623
#   Setting (1, 1): E = -0.016, winrate = 0.508, rounds = 610
# Global S = 1.5925, Global winrate = 0.6988
#
# 0.6988 1.5925330920153364
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.334, winrate = 0.667, rounds = 574
#   Setting (0, 1): E = 0.592, winrate = 0.796, rounds = 588
#   Setting (1, 0): E = 0.416, winrate = 0.708, rounds = 644
#   Setting (1, 1): E = -0.637, winrate = 0.818, rounds = 694
# Global S = 1.9794, Global winrate = 0.7500
#
# 0.75 1.9793681846051867
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.817, winrate = 0.908, rounds = 622
#   Setting (0, 1): E = 0.101, winrate = 0.550, rounds = 636
#   Setting (1, 0): E = 0.033, winrate = 0.516, rounds = 612
#   Setting (1, 1): E = -0.841, winrate = 0.921, rounds = 630
# Global S = 1.7913, Global winrate = 0.7244
#
# 0.7244 1.7912987678842696
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.120, winrate = 0.560, rounds = 616
#   Setting (0, 1): E = 0.481, winrate = 0.740, rounds = 620
#   Setting (1, 0): E = 0.754, winrate = 0.877, rounds = 642
#   Setting (1, 1): E = -0.434, winrate = 0.717, rounds = 622
# Global S = 1.7888, Global winrate = 0.7252
#
# 0.7252 1.7887527137032508
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.467, winrate = 0.734, rounds = 597
#   Setting (0, 1): E = 0.666, winrate = 0.833, rounds = 653
#   Setting (1, 0): E = 0.743, winrate = 0.871, rounds = 614
#   Setting (1, 1): E = -0.469, winrate = 0.734, rounds = 636
# Global S = 2.3447, Global winrate = 0.7936
#
# 0.7936 2.34471735445252
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.445, winrate = 0.723, rounds = 620
#   Setting (0, 1): E = 0.654, winrate = 0.827, rounds = 624
#   Setting (1, 0): E = 0.734, winrate = 0.867, rounds = 623
#   Setting (1, 1): E = -0.343, winrate = 0.671, rounds = 633
# Global S = 2.1754, Global winrate = 0.7716
#
# 0.7716 2.1753668020127295
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.564, winrate = 0.782, rounds = 587
#   Setting (0, 1): E = 0.545, winrate = 0.773, rounds = 629
#   Setting (1, 0): E = 0.618, winrate = 0.809, rounds = 638
#   Setting (1, 1): E = -0.607, winrate = 0.803, rounds = 646
# Global S = 2.3336, Global winrate = 0.7920
#
# 0.792 2.3335601770723877
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.448, winrate = 0.724, rounds = 609
#   Setting (0, 1): E = 0.655, winrate = 0.827, rounds = 637
#   Setting (1, 0): E = 0.741, winrate = 0.870, rounds = 633
#   Setting (1, 1): E = -0.481, winrate = 0.741, rounds = 621
# Global S = 2.3253, Global winrate = 0.7916
#
# 0.7916 2.3253046984749175
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.473, winrate = 0.737, rounds = 615
#   Setting (0, 1): E = 0.767, winrate = 0.883, rounds = 609
#   Setting (1, 0): E = 0.768, winrate = 0.884, rounds = 621
#   Setting (1, 1): E = -0.450, winrate = 0.725, rounds = 655
# Global S = 2.4585, Global winrate = 0.8060
#
# 0.806 2.4584992234047616
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.449, winrate = 0.724, rounds = 595
#   Setting (0, 1): E = 0.795, winrate = 0.897, rounds = 672
#   Setting (1, 0): E = 0.760, winrate = 0.880, rounds = 633
#   Setting (1, 1): E = -0.393, winrate = 0.697, rounds = 600
# Global S = 2.3966, Global winrate = 0.8036
#
# 0.8036 2.3965893039680326
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.446, winrate = 0.723, rounds = 621
#   Setting (0, 1): E = 0.702, winrate = 0.851, rounds = 637
#   Setting (1, 0): E = 0.684, winrate = 0.842, rounds = 640
#   Setting (1, 1): E = -0.458, winrate = 0.729, rounds = 602
# Global S = 2.2906, Global winrate = 0.7876
#
# 0.7876 2.2906283557839062
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.419, winrate = 0.710, rounds = 606
#   Setting (0, 1): E = 0.743, winrate = 0.871, rounds = 606
#   Setting (1, 0): E = 0.743, winrate = 0.872, rounds = 615
#   Setting (1, 1): E = -0.441, winrate = 0.721, rounds = 673
# Global S = 2.3461, Global winrate = 0.7916
#
# 0.7916 2.346113180520386
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.483, winrate = 0.742, rounds = 596
#   Setting (0, 1): E = 0.730, winrate = 0.865, rounds = 600
#   Setting (1, 0): E = 0.678, winrate = 0.839, rounds = 652
#   Setting (1, 1): E = -0.488, winrate = 0.744, rounds = 652
# Global S = 2.3789, Global winrate = 0.7972
#
# 0.7972 2.3788656482892083
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.704, winrate = 0.148, rounds = 2530
#   Setting (0, 1): E = 0.129, winrate = 0.565, rounds = 2476
#   Setting (1, 0): E = -0.107, winrate = 0.447, rounds = 2477
#   Setting (1, 1): E = 0.796, winrate = 0.102, rounds = 2517
# Global S = -1.4771, Global winrate = 0.3136
#
# Win rate: 0.3136 S: -1.477089493842998
# -1.477089493842998
# Iteration: 2
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.341, winrate = 0.670, rounds = 613
#   Setting (0, 1): E = 0.327, winrate = 0.663, rounds = 624
#   Setting (1, 0): E = -0.211, winrate = 0.394, rounds = 611
#   Setting (1, 1): E = 0.801, winrate = 0.100, rounds = 652
# Global S = -0.3439, Global winrate = 0.4524
#
# 0.4524 -0.3438735498503379
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.510, winrate = 0.755, rounds = 629
#   Setting (0, 1): E = 0.338, winrate = 0.669, rounds = 604
#   Setting (1, 0): E = 0.743, winrate = 0.872, rounds = 623
#   Setting (1, 1): E = -0.354, winrate = 0.677, rounds = 644
# Global S = 1.9453, Global winrate = 0.7432
#
# 0.7432 1.9452976448711086
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.402, winrate = 0.299, rounds = 659
#   Setting (0, 1): E = -0.720, winrate = 0.140, rounds = 578
#   Setting (1, 0): E = 0.699, winrate = 0.850, rounds = 645
#   Setting (1, 1): E = -0.492, winrate = 0.746, rounds = 618
# Global S = 0.0693, Global winrate = 0.5148
#
# 0.5148 0.06928657696782142
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.473, winrate = 0.736, rounds = 622
#   Setting (0, 1): E = 0.403, winrate = 0.701, rounds = 663
#   Setting (1, 0): E = -0.253, winrate = 0.373, rounds = 624
#   Setting (1, 1): E = 0.800, winrate = 0.100, rounds = 591
# Global S = -0.1782, Global winrate = 0.4860
#
# 0.486 -0.17815979526450754
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.700, winrate = 0.150, rounds = 627
#   Setting (0, 1): E = 0.525, winrate = 0.762, rounds = 640
#   Setting (1, 0): E = 0.440, winrate = 0.720, rounds = 600
#   Setting (1, 1): E = 0.611, winrate = 0.194, rounds = 633
# Global S = -0.3465, Global winrate = 0.4548
#
# 0.4548 -0.3465338972161122
#
# [CHSH Stats]
#   Setting (0, 0): E = -0.553, winrate = 0.223, rounds = 609
#   Setting (0, 1): E = -0.601, winrate = 0.199, rounds = 647
#   Setting (1, 0): E = 0.743, winrate = 0.872, rounds = 615
#   Setting (1, 1): E = -0.374, winrate = 0.687, rounds = 629
# Global S = -0.0379, Global winrate = 0.4932
#
# 0.4932 -0.03790431618412915
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.806, winrate = 0.903, rounds = 650
#   Setting (0, 1): E = 0.064, winrate = 0.532, rounds = 652
#   Setting (1, 0): E = -0.256, winrate = 0.372, rounds = 597
#   Setting (1, 1): E = 0.574, winrate = 0.213, rounds = 601
# Global S = 0.0402, Global winrate = 0.5136
#
# 0.5136 0.04024635580149938
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.660, winrate = 0.830, rounds = 606
#   Setting (0, 1): E = -0.608, winrate = 0.196, rounds = 663
#   Setting (1, 0): E = -0.163, winrate = 0.419, rounds = 602
#   Setting (1, 1): E = -0.087, winrate = 0.544, rounds = 629
# Global S = -0.0231, Global winrate = 0.4908
#
# 0.4908 -0.023127446770631846
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.800, winrate = 0.900, rounds = 591
#   Setting (0, 1): E = 0.168, winrate = 0.584, rounds = 642
#   Setting (1, 0): E = 0.161, winrate = 0.581, rounds = 639
#   Setting (1, 1): E = -0.793, winrate = 0.896, rounds = 628
# Global S = 1.9227, Global winrate = 0.7364
#
# 0.7364 1.922745697486591
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.556, winrate = 0.778, rounds = 613
#   Setting (0, 1): E = 0.495, winrate = 0.748, rounds = 630
#   Setting (1, 0): E = 0.640, winrate = 0.820, rounds = 628
#   Setting (1, 1): E = -0.218, winrate = 0.609, rounds = 629
# Global S = 1.9095, Global winrate = 0.7384
#
# 0.7384 1.9094521123842734
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.547, winrate = 0.773, rounds = 618
#   Setting (0, 1): E = 0.263, winrate = 0.632, rounds = 600
#   Setting (1, 0): E = 0.659, winrate = 0.829, rounds = 627
#   Setting (1, 1): E = -0.450, winrate = 0.725, rounds = 655
# Global S = 1.9193, Global winrate = 0.7408
#
# 0.7408 1.9193327640736628
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.499, winrate = 0.750, rounds = 639
#   Setting (0, 1): E = 0.188, winrate = 0.594, rounds = 623
#   Setting (1, 0): E = 0.694, winrate = 0.847, rounds = 653
#   Setting (1, 1): E = -0.255, winrate = 0.627, rounds = 585
# Global S = 1.6354, Global winrate = 0.7076
#
# 0.7076 1.6354406315398553
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.459, winrate = 0.729, rounds = 639
#   Setting (0, 1): E = 0.549, winrate = 0.774, rounds = 638
#   Setting (1, 0): E = 0.705, winrate = 0.853, rounds = 584
#   Setting (1, 1): E = -0.308, winrate = 0.654, rounds = 639
# Global S = 2.0209, Global winrate = 0.7504
#
# 0.7504 2.0208919549369426
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.164, winrate = 0.582, rounds = 627
#   Setting (0, 1): E = 0.786, winrate = 0.893, rounds = 664
#   Setting (1, 0): E = 0.792, winrate = 0.896, rounds = 595
#   Setting (1, 1): E = -0.189, winrate = 0.594, rounds = 614
# Global S = 1.9309, Global winrate = 0.7424
#
# 0.7424 1.9309406205709991
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.511, winrate = 0.755, rounds = 605
#   Setting (0, 1): E = 0.573, winrate = 0.786, rounds = 618
#   Setting (1, 0): E = 0.611, winrate = 0.806, rounds = 648
#   Setting (1, 1): E = -0.326, winrate = 0.663, rounds = 629
# Global S = 2.0206, Global winrate = 0.7528
#
# 0.7528 2.0205845961881472
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.506, winrate = 0.753, rounds = 627
#   Setting (0, 1): E = 0.570, winrate = 0.785, rounds = 646
#   Setting (1, 0): E = 0.698, winrate = 0.849, rounds = 622
#   Setting (1, 1): E = -0.345, winrate = 0.673, rounds = 605
# Global S = 2.1184, Global winrate = 0.7656
#
# 0.7656 2.118445321481567
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.511, winrate = 0.756, rounds = 622
#   Setting (0, 1): E = 0.637, winrate = 0.819, rounds = 645
#   Setting (1, 0): E = 0.627, winrate = 0.814, rounds = 601
#   Setting (1, 1): E = -0.297, winrate = 0.649, rounds = 632
# Global S = 2.0732, Global winrate = 0.7588
#
# 0.7588 2.0732195296259364
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.451, winrate = 0.725, rounds = 590
#   Setting (0, 1): E = 0.567, winrate = 0.784, rounds = 638
#   Setting (1, 0): E = 0.742, winrate = 0.871, rounds = 643
#   Setting (1, 1): E = -0.084, winrate = 0.542, rounds = 629
# Global S = 1.8443, Global winrate = 0.7316
#
# 0.7316 1.8443414558138762
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.624, winrate = 0.812, rounds = 601
#   Setting (0, 1): E = 0.619, winrate = 0.809, rounds = 656
#   Setting (1, 0): E = 0.548, winrate = 0.774, rounds = 624
#   Setting (1, 1): E = -0.532, winrate = 0.766, rounds = 619
# Global S = 2.3224, Global winrate = 0.7904
#
# 0.7904 2.3224418519203818
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.682, winrate = 0.841, rounds = 603
#   Setting (0, 1): E = 0.585, winrate = 0.793, rounds = 632
#   Setting (1, 0): E = 0.541, winrate = 0.770, rounds = 592
#   Setting (1, 1): E = -0.676, winrate = 0.838, rounds = 673
# Global S = 2.4837, Global winrate = 0.8112
#
# 0.8112 2.4836528842894734
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.717, winrate = 0.858, rounds = 628
#   Setting (0, 1): E = 0.402, winrate = 0.701, rounds = 622
#   Setting (1, 0): E = 0.376, winrate = 0.688, rounds = 628
#   Setting (1, 1): E = -0.723, winrate = 0.862, rounds = 622
# Global S = 2.2178, Global winrate = 0.7772
#
# 0.7772 2.2177586171585393
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.772, winrate = 0.886, rounds = 578
#   Setting (0, 1): E = 0.526, winrate = 0.763, rounds = 658
#   Setting (1, 0): E = 0.533, winrate = 0.767, rounds = 613
#   Setting (1, 1): E = -0.696, winrate = 0.848, rounds = 651
# Global S = 2.5268, Global winrate = 0.8144
#
# 0.8144 2.526756786492819
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.620, winrate = 0.810, rounds = 632
#   Setting (0, 1): E = 0.634, winrate = 0.817, rounds = 618
#   Setting (1, 0): E = 0.590, winrate = 0.795, rounds = 610
#   Setting (1, 1): E = -0.609, winrate = 0.805, rounds = 640
# Global S = 2.4541, Global winrate = 0.8068
#
# 0.8068 2.4540963061029326
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.734, winrate = 0.867, rounds = 609
#   Setting (0, 1): E = 0.518, winrate = 0.759, rounds = 631
#   Setting (1, 0): E = 0.498, winrate = 0.749, rounds = 641
#   Setting (1, 1): E = -0.667, winrate = 0.834, rounds = 619
# Global S = 2.4171, Global winrate = 0.8012
#
# 0.8012 2.417080263427591
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.651, winrate = 0.825, rounds = 630
#   Setting (0, 1): E = 0.555, winrate = 0.777, rounds = 620
#   Setting (1, 0): E = 0.559, winrate = 0.780, rounds = 644
#   Setting (1, 1): E = -0.667, winrate = 0.833, rounds = 606
# Global S = 2.4313, Global winrate = 0.8036
#
# 0.8036 2.431305238317861
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.689, winrate = 0.845, rounds = 611
#   Setting (0, 1): E = 0.486, winrate = 0.743, rounds = 584
#   Setting (1, 0): E = 0.483, winrate = 0.742, rounds = 650
#   Setting (1, 1): E = -0.792, winrate = 0.896, rounds = 655
# Global S = 2.4508, Global winrate = 0.8076
#
# 0.8076 2.4507790750391107
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.625, winrate = 0.812, rounds = 650
#   Setting (0, 1): E = 0.487, winrate = 0.743, rounds = 604
#   Setting (1, 0): E = 0.561, winrate = 0.780, rounds = 615
#   Setting (1, 1): E = -0.645, winrate = 0.823, rounds = 631
# Global S = 2.3174, Global winrate = 0.7904
#
# 0.7904 2.317353885189169
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.717, winrate = 0.858, rounds = 635
#   Setting (0, 1): E = 0.517, winrate = 0.758, rounds = 600
#   Setting (1, 0): E = 0.502, winrate = 0.751, rounds = 631
#   Setting (1, 1): E = -0.716, winrate = 0.858, rounds = 634
# Global S = 2.4517, Global winrate = 0.8072
#
# 0.8072 2.4516676068940666
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.649, winrate = 0.825, rounds = 616
#   Setting (0, 1): E = 0.493, winrate = 0.747, rounds = 651
#   Setting (1, 0): E = 0.583, winrate = 0.791, rounds = 628
#   Setting (1, 1): E = -0.577, winrate = 0.788, rounds = 605
# Global S = 2.3021, Global winrate = 0.7872
#
# 0.7872 2.302100258857268
#
# [CHSH Stats]
#   Setting (0, 0): E = 0.644, winrate = 0.822, rounds = 618
#   Setting (0, 1): E = 0.532, winrate = 0.766, rounds = 632
#   Setting (1, 0): E = 0.529, winrate = 0.764, rounds = 590
#   Setting (1, 1): E = -0.645, winrate = 0.823, rounds = 660
# Global S = 2.3499, Global winrate = 0.7944
#
# 0.7944 2.349926619380651
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 77
#      74 # print(deltas)
#      75 g = network_module.Game(deltas = deltas,guarantee_entanglement = True,fid = 0.9)
# ---> 77 result = g.start(10000, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
#      78 S = g.referee.compute_chsh_s()
#      79 print("Win rate:",result,"S:",S)
#
# File ~/Documents/Python/CHSH_Game/CHSH_GAME/network_module.py:599, in Game.start(self, games, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
#     596         self.successful_entanglements += 1
#     598 # Play a round and store the result in a variable
# --> 599 rnd = self.play_round(theta1,theta2,theta3,theta4,alphas_alice, alphas_bob)
#     601 # If the result is a win, add one to the win counter
#     602 if rnd:
#
# File ~/Documents/Python/CHSH_Game/CHSH_GAME/network_module.py:640, in Game.play_round(self, theta1, theta2, theta3, theta4, alphas_alice, alphas_bob)
#     638 self.r.protocols[0].sendBit('a.pp', 'a')
#     639 self.r.protocols[0].sendBit('b.pp', 'b')
# --> 640 self.tl.run()
#     642 #Get whether Alice and Bob won or lost, and return it to the start function
#     643 return self.referee.get_result()
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/sequence/kernel/timeline.py:141, in Timeline.run(self)
#     138     self.time = event.time
#     140     log.logger.debug("Event #{}: process owner={}, activation={}".format(self.run_counter, event.process.owner, event.process.activation))
# --> 141     event.process.run()
#     142     self.run_counter += 1
#     144 self.is_running = False
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/sequence/kernel/process.py:33, in Process.run(self)
#      26 def run(self) -> None:
#      27     """Method to execute process.
#      28
#      29     Will run the `activation_method` method of `owner` with
#      30     `activation_args` passed as args, and 'activation_kwargs' passed as kwargs.
#      31     """
# ---> 33     return getattr(self.owner, self.activation)(*self.activation_args, **self.activation_kwargs)
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/sequence/topology/node.py:158, in Node.receive_message(self, src, msg)
#     156 if msg.receiver is not None:
#     157     for protocol in self.protocols:
# --> 158         if protocol.name == msg.receiver and protocol.received_message(src, msg):
#     159             return
#     160 else:
#
# File ~/Documents/Python/CHSH_Game/CHSH_GAME/network_module.py:274, in RefereeProtocol.received_message(self, src, msg)
#     272 circ.measure(0)
#     273 circ.measure(1)
# --> 274 res = self.tl.quantum_manager.run_circuit(circ, self.keys, random.random())
#     275 self.adjudicate_round(self.inputs, res)
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/sequence/kernel/quantum_manager.py:181, in QuantumManagerKet.run_circuit(self, circuit, keys, meas_samp)
#     179 def run_circuit(self, circuit: Circuit, keys: List[int], meas_samp=None) -> Dict[int, int]:
#     180     super().run_circuit(circuit, keys, meas_samp)
# --> 181     new_state, all_keys, circ_mat = self._prepare_circuit(circuit, keys)
#     183     new_state = circ_mat @ new_state
#     185     if len(circuit.measured_qubits) == 0:
#     186         # set state, return no measurement result
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/sequence/kernel/quantum_manager.py:109, in QuantumManager._prepare_circuit(self, circuit, keys)
#     106     new_state = kron(new_state, state)
#     108 # get circuit matrix; expand if necessary
# --> 109 circ_mat = circuit.get_unitary_matrix()
#     110 if circuit.size < len(all_keys):
#     111     # pad size of circuit matrix if necessary
#     112     diff = len(all_keys) - circuit.size
#
# File ~/Documents/Python/CHSH_Game/CHSH_GAME/network_module.py:139, in CustomCircuit.get_unitary_matrix(self)
#     137         else:
#     138             raise NotImplementedError
# --> 139     self._cache = gate_sequence_product(qc.propagators()).full()
#     141 return self._cache
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/qutip_qip/circuit/circuit.py:883, in QubitCircuit.propagators(self, expand, ignore_measurement)
#     881         if expand:
#     882             all_targets = gate.get_all_qubits()
# --> 883             qobj = expand_operator(
#     884                 qobj, dims=self.dims, targets=all_targets
#     885             )
#     886     U_list.append(qobj)
#     887 return U_list
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/qutip_qip/operations/gates.py:1328, in expand_operator(oper, N, targets, dims, cyclic_permutation, dtype)
#    1326 for i, ind in enumerate(rest_pos):
#    1327     new_order[ind] = rest_qubits[i]
# -> 1328 id_list = [identity(dims[i]) for i in rest_pos]
#    1329 out = tensor([oper] + id_list).permute(new_order)
#    1330 if parse_version(qutip.__version__) >= parse_version("5.dev"):
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/qutip_qip/operations/gates.py:1328, in <listcomp>(.0)
#    1326 for i, ind in enumerate(rest_pos):
#    1327     new_order[ind] = rest_qubits[i]
# -> 1328 id_list = [identity(dims[i]) for i in rest_pos]
#    1329 out = tensor([oper] + id_list).permute(new_order)
#    1330 if parse_version(qutip.__version__) >= parse_version("5.dev"):
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/qutip/core/operators.py:811, in qeye(dimensions, dtype)
#     771 """
#     772 Identity operator.
#     773
#    (...)
#     808
#     809 """
#     810 dtype = dtype or settings.core["default_dtype"] or _data.Dia
# --> 811 dimensions = Space(dimensions)
#     812 return Qobj(_data.identity[dtype](dimensions.size), dims=[dimensions]*2,
#     813             isherm=True, isunitary=True, copy=False)
#
# File /media/cadmin/ExtremeSSD/envs/Quantum/lib/python3.10/site-packages/qutip/core/dimensions.py:399, in MetaSpace.__call__(cls, rep, *args)
#     396 if len(args) == 0:
#     397     # Empty space: a Field.
#     398     cls = Field
# --> 399 elif len(args) == 1 and args[0] == 1:
#     400     # Space(1): a Field.
#     401     cls = Field
#     402 elif len(args) == 1 and isinstance(args[0], Dimensions):
#     403     # Making a Space out of a Dimensions object: Super Operator.
#
# KeyboardInterrupt:

# %%
import statistics
print("Mean validation Bayesian Optimization:",statistics.mean(BO_res))
print("Standard Deviation Bayesian Optimization:",statistics.stdev(BO_res))

# %%
print("Mean validation Nelder-Mead:",statistics.mean(NM_res))
print("Standard Deviation Nelder-Mead:",statistics.stdev(NM_res))

# %%
print("Mean validation COBYLA:",statistics.mean(COB_res))
print("Standard Deviation COBYLA:",statistics.stdev(COB_res))

# %%
BO_mean = np.array(BO_conv).mean(axis=0)
BO_std  = np.array(BO_conv).std(axis=0)

# NM_mean = NM_conv.mean(axis=0)
# NM_std  = np.array(NM_conv).std(axis=0)

COB_mean = np.array(COB_conv).mean(axis=0)
COB_std  = np.array(COB_conv).std(axis=0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Bayesian Optimization
plt.plot(BO_mean, label='BO mean')
plt.fill_between(range(len(BO_mean)), BO_mean-BO_std, BO_mean+BO_std, alpha=0.3)

# #Nelder-Mead
# plt.plot(NM_mean, label='COBYLA mean')
# plt.fill_between(range(len(NM_mean)), NM_mean-NM_std , NM_mean+NM_std, alpha=0.3)

# COBYLA
plt.plot(COB_mean, label='COBYLA mean')
plt.fill_between(range(len(COB_mean)), COB_mean-COB_std, COB_mean+COB_std, alpha=0.3)
plt.xlim(0, 29)
plt.xlabel('Iteration')
plt.ylabel('Best S so far')
plt.title('Convergence (Mean ± Std) over Multiple Experiments')
plt.legend()
plt.grid(True)
plt.show()

# %%
BO_time

# %%
COB_time
